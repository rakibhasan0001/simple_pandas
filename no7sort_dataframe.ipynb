# %%
import pandas as pd
movies=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies['title']
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
movies.title.sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
#another mathod
movies['title'].sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
#stop ascending order 
movies['title'].sort_values(ascending=False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movies.sort_values(['star_rating', 'title'])
# Out:
#      star_rating                                          title  \
# 941          7.4                               A Bridge Too Far
# 938          7.4                            Alice in Wonderland
# 975          7.4                    Back to the Future Part III
# 933          7.4                                    Beetlejuice
# 972          7.4                                 Blue Valentine
# ..           ...                                            ...
# 7            8.9  The Lord of the Rings: The Return of the King
# 3            9.0                                The Dark Knight
# 2            9.1                         The Godfather: Part II
# 1            9.2                                  The Godfather
# 0            9.3                       The Shawshank Redemption
#
#     content_rating      genre  duration  \
# 941             PG      Drama       175
# 938              G  Animation        75
# 975             PG  Adventure       118
# ...

# %%
movies.sort_values(['content_rating', 'duration'], ascending= [True, False]) 
#we get the high duration movie first
# Out:
#      star_rating                               title content_rating  \
# 445          7.9                The Ten Commandments       APPROVED
# 767          7.6     It's a Mad, Mad, Mad, Mad World       APPROVED
# 444          7.9                        My Fair Lady       APPROVED
# 557          7.8                        Mary Poppins       APPROVED
# 95           8.4                       All About Eve       APPROVED
# ..           ...                                 ...            ...
# 913          7.5                            Suspiria              X
# 486          7.8                        Evil Dead II              X
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
#
#          genre  duration                                        actors_list
# ...

# %%
movies.sort_values(['content_rating', 'duration'], ascending= [False, False])
# Out:
#      star_rating                               title content_rating  \
# 86           8.4                  A Clockwork Orange              X
# 387          8.0                     Midnight Cowboy              X
# 913          7.5                            Suspiria              X
# 486          7.8                        Evil Dead II              X
# 17           8.7                       Seven Samurai        UNRATED
# ..           ...                                 ...            ...
# 513          7.8      Invasion of the Body Snatchers       APPROVED
# 713          7.6                     The Jungle Book       APPROVED
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
#
#          genre  duration                                        actors_list
# ...

# %%
movies.sort_values(['content_rating', 'duration'],ascending=[False,True])
#more rating ,duration less
# Out:
#      star_rating                               title content_rating  \
# 486          7.8                        Evil Dead II              X
# 913          7.5                            Suspiria              X
# 387          8.0                     Midnight Cowboy              X
# 86           8.4                  A Clockwork Orange              X
# 389          8.0                              Freaks        UNRATED
# ..           ...                                 ...            ...
# 767          7.6     It's a Mad, Mad, Mad, Mad World       APPROVED
# 445          7.9                The Ten Commandments       APPROVED
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 936          7.4                           True Grit            NaN
# 649          7.7                   Where Eagles Dare            NaN
#
#          genre  duration                                        actors_list
# ...

# %%
print(movies.content_rating.describe())
print(movies.duration.describe())
# Out:
# count     976
# unique     12
# top         R
# freq      460
# Name: content_rating, dtype: object
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64
