# %%
![](image name)
# Out:
# '[]' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ![](main-qimg-f673ad3e7a1cf701af3fbd4768d89eca.jfif)

# %%
import pandas as pd
ufo=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv',nrows=3)
ufo.head()
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00

# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
movies=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv',usecols=[0,3])
movies.head()
#u can also give usecols=[star_rating,genre]
# Out:
#    star_rating   genre
# 0          9.3   Crime
# 1          9.2   Crime
# 2          9.1   Crime
# 3          9.0  Action
# 4          8.9   Crime

# %%
for i in movies.genre:
    print(i)
# Out:
# Crime
# Crime
# Crime
# Action
# Crime
# Drama
# Western
# Adventure
# Biography
# Drama
# Adventure
# Action
# Action
# Drama
# Adventure
# Adventure
# Drama
# Drama
# Biography
# Action
# Action
# Crime
# Drama
# Crime
# Drama
# Comedy
# Western
# Drama
# Crime
# Comedy
# Animation
# Biography
# Drama
# Drama
# Crime
# Comedy
# Action
# Action
# Mystery
# Horror
# Crime
# Drama
# Biography
# Action
# Action
# Action
# Mystery
# Drama
# Comedy
# Crime
# Drama
# Drama
# Comedy
# Drama
# Adventure
# Animation
# Drama
# Horror
# Drama
# Western
# Comedy
# Animation
# Horror
# Crime
# Animation
# Crime
# Comedy
# Drama
# Adventure
# Animation
# Comedy
# Adventure
# Drama
# Drama
# Drama
# Action
# Mystery
# Drama
# Crime
# Crime
# Action
# Animation
# Action
# Drama
# Drama
# Adventure
# Crime
# Drama
# Comedy
# Drama
# Crime
# Drama
# Crime
# Comedy
# Comedy
# Drama
# Action
# Comedy
# Crime
# Biography
# Action
# Adventure
# Drama
# Comedy
# Drama
# Film-Noir
# Comedy
# Western
# ...

# %%
for index,row in movies.iterrows():
    print(index,row.genre,row.star_rating)
#here key is index and value is row
# Out:
# 0 Crime 9.3
# 1 Crime 9.2
# 2 Crime 9.1
# 3 Action 9.0
# 4 Crime 8.9
# 5 Drama 8.9
# 6 Western 8.9
# 7 Adventure 8.9
# 8 Biography 8.9
# 9 Drama 8.9
# 10 Adventure 8.8
# 11 Action 8.8
# 12 Action 8.8
# 13 Drama 8.8
# 14 Adventure 8.8
# 15 Adventure 8.7
# 16 Drama 8.7
# 17 Drama 8.7
# 18 Biography 8.7
# 19 Action 8.7
# 20 Action 8.7
# 21 Crime 8.7
# 22 Drama 8.7
# 23 Crime 8.7
# 24 Drama 8.7
# 25 Comedy 8.6
# 26 Western 8.6
# 27 Drama 8.6
# 28 Crime 8.6
# 29 Comedy 8.6
# 30 Animation 8.6
# 31 Biography 8.6
# 32 Drama 8.6
# 33 Drama 8.6
# 34 Crime 8.6
# 35 Comedy 8.6
# 36 Action 8.6
# 37 Action 8.6
# 38 Mystery 8.6
# 39 Horror 8.6
# 40 Crime 8.5
# 41 Drama 8.5
# 42 Biography 8.5
# 43 Action 8.5
# 44 Action 8.5
# 45 Action 8.5
# 46 Mystery 8.5
# 47 Drama 8.5
# 48 Comedy 8.5
# 49 Crime 8.5
# 50 Drama 8.5
# 51 Drama 8.5
# 52 Comedy 8.5
# 53 Drama 8.5
# 54 Adventure 8.5
# 55 Animation 8.5
# 56 Drama 8.5
# 57 Horror 8.5
# 58 Drama 8.5
# 59 Western 8.5
# 60 Comedy 8.5
# 61 Animation 8.5
# ...

# %% [markdown]
# # if i want to take only integer value

# %%
import numpy as np
movies.select_dtypes(include=[np.number])
# Out:
#      star_rating
# 0            9.3
# 1            9.2
# 2            9.1
# 3            9.0
# 4            8.9
# ..           ...
# 974          7.4
# 975          7.4
# 976          7.4
# 977          7.4
# 978          7.4
#
# [979 rows x 1 columns]

# %%
movies.describe(include=['object'])
# Out:
#         genre
# count     979
# unique     16
# top     Drama
# freq      278

# %%
import pandas as pd
movies=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')
movies.head()
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
import pandas as pd
movies=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')
movies.head()
movies.describe(include='all')
#describe(include=['dtype','dtype',....])
# Out:
#         star_rating      title content_rating  genre    duration  \
# count    979.000000        979            976    979  979.000000
# unique          NaN        975             12     16         NaN
# top             NaN  True Grit              R  Drama         NaN
# freq            NaN          2            460    278         NaN
# mean       7.889785        NaN            NaN    NaN  120.979571
# std        0.336069        NaN            NaN    NaN   26.218010
# min        7.400000        NaN            NaN    NaN   64.000000
# 25%        7.600000        NaN            NaN    NaN  102.000000
# 50%        7.800000        NaN            NaN    NaN  117.000000
# 75%        8.100000        NaN            NaN    NaN  134.000000
# max        9.300000        NaN            NaN    NaN  242.000000
#
#                                               actors_list
# count                                                 979
# unique                                                969
# ...
