# %%
import pandas as pd
games=pd.read_csv('video_games.csv')
games.head()
# Out:
#                       Title  Features.Handheld?  ...  Length.Main Story.Polled  Length.Main Story.Rushed
# 0         Super Mario 64 DS                True  ...                        21                  9.700000
# 1    Lumines: Puzzle Fusion                True  ...                         3                  9.583333
# 2        WarioWare Touched!                True  ...                        30                  1.433333
# 3  Hot Shots Golf: Open Tee                True  ...                         0                  0.000000
# 4              Spider-Man 2                True  ...                        23                  5.333333
#
# [5 rows x 36 columns]

# %%
games.Title.str.upper()
#you have to mind it to use str
# Out:
# 0              SUPER MARIO 64 DS
# 1         LUMINES: PUZZLE FUSION
# 2             WARIOWARE TOUCHED!
# 3       HOT SHOTS GOLF: OPEN TEE
# 4                   SPIDER-MAN 2
#                   ...
# 1207      SECRET FILES: TUNGUSKA
# 1208              FADING SHADOWS
# 1209           HAIL TO THE CHIMP
# 1210      SECRET FILES: TUNGUSKA
# 1211              CHICKEN HUNTER
# Name: Title, Length: 1212, dtype: object

# %%
games.Title.str.contains('Spider')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1207    False
# 1208    False
# 1209    False
# 1210    False
# 1211    False
# Name: Title, Length: 1212, dtype: bool

# %%
games.Title.str.replace('Super','dumb').str.replace('Hot Shots Golf: Open Tee','rakib hasan')
# Out:
# 0             dumb Mario 64 DS
# 1       Lumines: Puzzle Fusion
# 2           WarioWare Touched!
# 3                  rakib hasan
# 4                 Spider-Man 2
#                  ...
# 1207    Secret Files: Tunguska
# 1208            Fading Shadows
# 1209         Hail to the Chimp
# 1210    Secret Files: Tunguska
# 1211            Chicken Hunter
# Name: Title, Length: 1212, dtype: object
