# %%
import pandas as pd
pd.read_table('http://bit.ly/movieusers',sep='',header=None,names=)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# <ipython-input-3-f6aaa0ac00fd> in <module>
#       1 import pandas as pd
# ----> 2 pd.read_table('http://bit.ly/movieusers',sep='',header=None)
#
# ...

# %%
help(pd.read_table)
# Out:
# Help on function read_table in module pandas.io.parsers:
#
# ...

# %%
settingName=['A','B','C','D','E','F']
pd.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv',header=None,names=settingName)
# Out:
#              A         B                                      C  \
# 0     order_id  quantity                              item_name
# 1            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                                   Izze
# 3            1         1                       Nantucket Nectar
# 4            1         1  Chips and Tomatillo-Green Chili Salsa
# ...        ...       ...                                    ...
# 4618      1833         1                          Steak Burrito
# 4619      1833         1                          Steak Burrito
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
# 4622      1834         1                     Chicken Salad Bowl
#
#                                                       D           E   F
# 0                                    choice_description  item_price NaN
# ...

# %%
#NOTE
#pandas make table only tab devied column

# %%
settingName=['A','B','C','D','E','F']
users=pd.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv',header=None,names=settingName)
users.head()#if we make object
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0f51c0fcbc97> in <module>
#       1 settingName=['A','B','C','D','E','F']
# ----> 2 users=pd.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv',header=None,names=settingName)
#       3 users.head()#if we make object
#
# NameError: name 'pd' is not defined
