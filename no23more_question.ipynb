# %% [markdown]
# # search pandas API refarance

# %%
import pandas as pd
ufo=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.sample(n=3)#it will choose random three row
# Out:
#                City Colors Reported Shape Reported State             Time
# 1236   Whiteman AFB             NaN           DISK    MO  6/15/1966 21:00
# 17871         Dover             NaN       TRIANGLE    DE  11/3/2000 19:40
# 11920       Lincoln             NaN          LIGHT    NE   8/1/1998 22:30

# %%
ufo.sample(n=3,random_state=4)
# Out:
#             City Colors Reported Shape Reported State             Time
# 10201  Oceanside          ORANGE          OTHER    CA   5/2/1997 22:00
# 11407  Whitefish             NaN            NaN    MT  4/12/1998 23:00
# 10342     Renton             NaN           DISK    WA   6/8/1997 19:16

# %%
ufo.sample(frac=0.75,random_state=2)#it will give 75% of data
# Out:
#                                                     City Colors Reported  \
# 7236                                            Mesquite             NaN
# 14432                                          Pittsburg             NaN
# 4559                                              Mondel             NaN
# 5356                                              Camden             NaN
# 10323                                           Richmond             NaN
# ...                                                  ...             ...
# 2369                                          Texas City             NaN
# 3143   Fairbanks, Trans Alaskan Pipeline haul road 25...             NaN
# 17338                                               Erie             NaN
# 11905                                             Auanga             NaN
# 2644                                            Westline             NaN
#
#       Shape Reported State              Time
# 7236           OTHER    NV  11/25/1993 15:00
# ...

# %%
#this code is for machine learning
test=ufo.loc[~ufo.index.isin(train.index),:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d600d9a215e9> in <module>
#       1 #this code is for machine learning
# ----> 2 test=ufo.loc[~ufo.index.isin(train.index),:]
#
# NameError: name 'train' is not defined
